# %% [markdown]
# ## TRACER 17 JUNE 2022
#
# ### Lightning for all RHIs
#
# [Lightning Data for June 17th](http://pogo.tosm.ttu.edu/data/TRACER/)

# %%
import matplotlib.pyplot as plt
import pyart
import numpy as np
import cartopy.crs as ccrs
import pandas as pd
import xarray as xr
from datetime import datetime, date, time, timedelta
import pyart.graph.cm as pcm
import warnings
warnings.filterwarnings("ignore")

from lmatools.coordinateSystems import RadarCoordinateSystem, GeographicSystem, TangentPlaneCartesianSystem, MapProjection
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead

# %% [markdown]
# ### [LMAinterceptRHI](https://github.com/jcssouza/LMAinterceptRHI)

# %%
import sys
sys.path.append("./LMAinterceptRHI/")
# Adapted functions from LMAinterceptRHI
from radarlma2local import geo_to_tps
from ortho_proj import rot_mat_lma, close_sources, closest_pt_radarloc
from radar_processing import r_z_centers_edges_mesh
from interp_funcs import centers_to_edges_1d, coords_2d

# %%
from shapely.geometry import Polygon, Point, MultiPoint

class RadarLMASubsetter:
    def __init__(self, radar, lma, sweep_id=0):
        self.radar = radar
        self.lma = lma
        
        # -- Get radar time
        d = date(int(radar.time['units'][14:18]),int(radar.time['units'][19:21]),int(radar.time['units'][22:24]))
        t = time(int(radar.time['units'][25:27]),int(radar.time['units'][28:30]),int(radar.time['units'][31:33]))
        self.radar_time = datetime.combine(d,t)
        
        print('Radar scan type: ' + radar.scan_type)
        print('Sweep: ', sweep_id, 'of', radar.nsweeps)
        print(self.radar_time)
        
        # -- Initialize coordinate systems
        ctrlat, ctrlon, ctralt = radar.latitude['data'][0], radar.longitude['data'][0], radar.altitude['data'][0]
        self.geo = GeographicSystem()
        self.tps = TangentPlaneCartesianSystem(ctrlat, ctrlon, ctralt)
        self.rcs = RadarCoordinateSystem(ctrlat, ctrlon, ctralt)

    
        # -- Radar scan geometry: centers and edges of each gate
        RZ_centers, RZ_edges = r_z_centers_edges_mesh(radar, sweep_id)
        self.r_c = RZ_centers[:,:,0]
        self.z_c = RZ_centers[:,:,1]
        self.r_e = RZ_edges[:,:,0]
        self.z_e = RZ_edges[:,:,1]

        # Radar shape
        # -- To filter VHF sources out of the radar scan domain
        # --- Create the polygon: all ranges, lowest and highest elevation
        self.scan_poly = Polygon(np.append(
                np.append(RZ_edges[-1, :-1], RZ_edges[0, :-1], axis = 0), 
                RZ_edges[:, - 1], axis = 0))
        # scan_poly
        
    
    def lightning_within_time(self, seconds, max_alt=18e3, max_chi2=1.0, min_station=6):
        lma_data = self.lma
        radar_time = self.radar_time
        
        # Filter time and altitude
        sources = (lma_data.event_altitude < max_alt) & (abs( (np.datetime64(radar_time) - lma_data.event_time)/ np.timedelta64(1, 's') ) < seconds) 
        subset = lma_data[{'number_of_events': sources}]

        flashes_ids = np.unique(subset.event_parent_flash_id).astype(int)
        print(f'{len(flashes_ids)} flashes in {2*seconds} second interval near scan.')

        
        # Select events info for individual flash id ('number_of_events' dimension)
        # nid = 64
        # one_id = lma_data.event_parent_flash_id == flashes_ids[nid]
        # flash_events = lma_data[{'number_of_events': one_id}]

        # Filter data
        filter_events = (subset.event_chi2 < max_chi2) & (subset.event_stations > min_station)
        filter_events
        filtered = subset[{'number_of_events':filter_events}]

        # Only one flash events info in the dataset
        all_dims = dict(filtered.dims)
        all_dims.pop('number_of_events') #all dims will no longer have 'number of flashes’
        return filtered.drop_dims(all_dims.keys())
    
    def plot_lightning_near_scan_time(self, seconds,  **kwargs):
        radar = self.radar
        
        events_near = self.lightning_within_time(seconds, **kwargs)
        # Quick look at RHI relative to the selected lightning before coordinate transformations
        fig, ax = plt.subplots(1,1)
        flash_time = np.sort(events_near.event_time)
        loc_lma = ax.scatter(events_near.event_longitude, events_near.event_latitude,
                              marker = '.', s = 9, c = (flash_time - flash_time[0]), cmap = 'viridis',alpha=0.9)
        loc_radar = ax.scatter(radar.longitude['data'],radar.latitude['data'],
                                color = 'brown', marker = 's', s = 60)
        loc_rhi = ax.plot([radar.longitude['data'], radar.gate_longitude['data'][0][-1]],
                           [radar.latitude['data'], radar.gate_latitude['data'][0][-1]],
                           color = 'black')
        return ax
        # plt.axis((-95.5, -95.3, 29.65, 29.85))

    def find_lightning_distances_near_scan_time(self, seconds, distance, **kwargs):
        events_near = self.lightning_within_time(seconds, **kwargs)
        
        radar = self.radar

        # --- Orthogonal projection/ Matrix Rotation of the LF sources
        Xlma,Ylma,Zlma = geo_to_tps(events_near, radar)   # Filter does not have altitude
        XYZlma = np.column_stack((Xlma, Ylma, Zlma))
        lma_file_ortho = rot_mat_lma(radar, XYZlma, -1)  # -1 for counterclockwise

        # 1st STEP
        # -- Find and store sources within a certain ds distance
        ds = distance # m threshold
        r_cls, z_cls, y_min = close_sources(self.r_c, self.z_c, lma_file_ortho, ds)
        # -- Selected LMA sources inside the radar scan
        lma_shp = MultiPoint(tuple(np.vstack((r_cls, z_cls)).transpose()))
        R_cls = [] 
        Z_cls = []
        Y_min = []
        for i in np.arange(len(r_cls)):
            if self.scan_poly.contains(lma_shp[i]) == True:
                R_cls.append(np.asarray(lma_shp[i].coords[0])[0])
                Z_cls.append(np.asarray(lma_shp[i].coords[0])[1])
                Y_min.append(y_min[i])
        R_cls = np.asarray(R_cls)
        Z_cls = np.asarray(Z_cls)
        Y_min = np.asarray(Y_min)
        
        return R_cls, Z_cls, Y_min
    
    def radar_gate_at_lightning_source(self, R_cls, Zcls, Y_min):
        
        radar = self.radar
        
        # ASSUME Y = 0 is the location of the scan plane
        int_point1 = [np.array([R_cls[i], 0 , Z_cls[i]]) for i in np.arange(R_cls.size)]

        # 2o STEP
        # Transform from Rotationed Coordinate system Tangent Plane to Tangent Plan (rotates clockwise = 1)
        int_point2 = rot_mat_lma(radar, int_point1, 1)

        # 3o STEP
        # Tangent Plan to ECEF
        int_point3 = [self.tps.fromLocal(int_point2[i,:][:,None]) for i in np.arange(R_cls.size)]

        # 4o STEP
        # Transform from ECEF to Radar Coordinate System
        int_point4 = [self.rcs.fromECEF(int_point3[i][0],int_point3[i][1],int_point3[i][2]) for i in np.arange(R_cls.size)]

        # 5o STEP
        # Find closest point to RHI - Elevation and Range
        cls_r_idx = [closest_pt_radarloc(radar, int_point4[i])[0]  for i in np.arange(R_cls.size)]    # Radius index
        cls_az_idx = [closest_pt_radarloc(radar, int_point4[i])[1]  for i in np.arange(R_cls.size)]   # Azimuth index
        cls_elev_idx = [closest_pt_radarloc(radar, int_point4[i])[2]  for i in np.arange(R_cls.size)] # Elevation index
        
        return cls_r_idx, cls_az_idx, cls_elev_idx

# %%
class OverlayPlotter:
    
    def __init__(self, subsetter, seconds, distance):
        self.subsetter = subsetter
        self.radar = subsetter.radar
        self.r_e, self.z_e = subsetter.r_e, subsetter.z_e
        self.R_cls, self.Z_cls, self.Y_min = subsetter.find_lightning_distances_near_scan_time(seconds, distance)
        
    def plot(self, field='reflectivity', 
             cbar_range={'reflectivity':(0,60)},
             units={'reflectivity':'dBZ'},
             mask_field = 'reflectivity',
             mask_field_thresh=-10, distance_max = 1000):
        
        radar = self.radar
        R_cls, Z_cls, Y_min = self.R_cls, self.Z_cls, self.Y_min
        r_e, z_e = self.r_e, self.z_e
        
        # -- For plots below
        # -- Selecting coordinates and values for images below
        sel = [int(radar.sweep_start_ray_index['data'][0]), int(radar.sweep_end_ray_index['data'][0])]
        values = np.ma.getdata(radar.fields[field]['data'][sel[0] : sel[1]+1, :])
        mask_values = np.ma.getdata(radar.fields[mask_field]['data'][sel[0] : sel[1]+1, :])
        values[np.where(mask_values <= mask_field_thresh)] = 'nan'
        re = r_e[sel[0]: sel[1]+2]
        ze = z_e[sel[0]: sel[1]+2]

        if field in cbar_range:
            vmin, vmax = cbar_range[field]
        else:
            vmin, vmax = np.nanmin(values), np.nanmax(values)
        fig = plt.figure(figsize=(12, 8), dpi=180)
        ax1 = fig.add_subplot(111)
        cs = ax1.pcolormesh(re/1000, ze/1000, values, vmin = vmin, vmax = vmax, cmap = pcm.LangRainbow12)
        llma = plt.scatter(R_cls/1000,  Z_cls/1000, c = abs(Y_min), 
                           edgecolor = 'black', cmap = 'Reds_r', marker = "X", 
                           s = 200, alpha = 0.5, vmin = 0, vmax = distance_max)
        plt.xlim(10,40)
        plt.ylim(0,12)

        # -- cbar
        cb_ax = fig.add_axes([1.01, 0.13, 0.02, 0.75])
        cbar = fig.colorbar(cs, cax=cb_ax)
        cbar.set_label(units[field], size=15)
        cbar.ax.tick_params(labelsize=11)

        llma_ax = fig.add_axes([0.92, 0.13, 0.02, 0.75])
        cbar2 = fig.colorbar(llma, cax=llma_ax)
        cbar2.set_label('Orthogonal Distance (m)', size=15)
        cbar2.ax.tick_params(labelsize=11)

        fig.text(0.55, 0.9,self.subsetter.radar_time.strftime("%d %B %Y %H:%M:%S") + 
                 f' - VHF sources within {ds} m from the RHI scan', 
                 va='center', ha='center', fontsize = 15)
        fig.text(0.5, 0.05, 'Distance from radar (km)', va='center', ha='center', fontsize = 15)
        fig.text(0.09, 0.5, 'Distance above radar (km)', va='center', ha='center', rotation='vertical', fontsize = 15)

        return fig

# %% [markdown]
# ### Lightning
#
# One file has the whole day.

# %%
# Read lma file
lightning_file = '/data/Houston/LIGHTNING/6sensor_minimum/LYLOUT_220617_000000_86400_map500m.nc'
lma_data = xr.open_dataset(lightning_file)
# lma_data.event_time.values = pd.to_datetime(lma_data.event_time.values.astype('M8[us]')).to_pydatetime()

# %% [markdown]
# ### Subsetting and plotting

# %%
import os
from pathlib import Path
figures_out = './cases/figures/0617rhi'

Path(figures_out).mkdir(parents=True, exist_ok=True)

from glob import glob
all_radar_files = sorted(glob("houcsapr2cfrS2.a1_proc/houcsapr2cfrS2.a1.*_proc.nc"))

# %%
units={'reflectivity':'Reflectivity (dBZ)',
   'differential_reflectivity':'Differential Reflecivity (dB)',
   'copol_correlation_coeff':'Correlation Coeff. (unitless)',
   'normalized_coherent_power':'Normalized Coherent Power (dB)',
   'specific_differential_phase':'Specific Differential Phase (deg/km)',
   'KDP_CSU':'Specific Differential Phase (deg/km)',
   }

# Defaults to min, max
cbar_range={'reflectivity':(0,65),
    'differential_reflectivity':(-1, 5),
    'copol_correlation_coeff':(.90, 1.0),
    'KDP_CSU':(-15, 15),
   }

seconds = 30
ds = 1000

# %%
def plot_one_radar_file(figure_path, radar_filename):
    
    radar = pyart.io.read(radar_filename)
    if radar.scan_type=='rhi':
        subsetter = RadarLMASubsetter(radar,lma_data)
        plotter = OverlayPlotter(subsetter, seconds, ds)
        
        outfile_time_base = os.path.join(figure_path, 
                                         subsetter.radar_time.strftime('%Y%m%d_%H%M%S.'))
        
        plan_ax = subsetter.plot_lightning_near_scan_time(30)
        plan_ax.axis((-95.7, -95.2, 29.5, 30.0))
        plan_ax.figure.savefig(outfile_time_base + 'plan.png')
        plt.close(plan_ax.figure)
                               
        fig = plotter.plot('normalized_coherent_power', units=units,
            cbar_range=cbar_range, distance_max=ds)
        outfilename = outfile_time_base + 'normalized_coherent_power' + '.png'
        fig.savefig(outfilename)
        plt.close(fig)
        
        fields_to_plot = ['reflectivity', 'differential_reflectivity',
                     'specific_differential_phase', 'KDP_CSU',
                     'copol_correlation_coeff']
        for field in fields_to_plot:           
            outfilename = outfile_time_base + field + '.png'
            
            fig = plotter.plot(field, units=units,
                               mask_field = 'normalized_coherent_power',
                               mask_field_thresh=0.5,
                               cbar_range=cbar_range, distance_max=ds)
            fig.savefig(outfilename)
            plt.close(fig)
                               
for radar_file in all_radar_files:
    plot_one_radar_file(figures_out, radar_file)
# Out:
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a615a500>
# 2022-06-17 19:30:17
# 22 flashes in 60 second interval near scan.
# 22 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a647bbe0>
# 2022-06-17 19:30:32
# 21 flashes in 60 second interval near scan.
# 21 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a67f4a00>
# 2022-06-17 19:30:46
# 27 flashes in 60 second interval near scan.
# 27 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a6682140>
# 2022-06-17 19:31:02
# 33 flashes in 60 second interval near scan.
# 33 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a79497b0>
# 2022-06-17 19:31:42
# 37 flashes in 60 second interval near scan.
# 37 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a773b280>
# 2022-06-17 19:31:56
# 33 flashes in 60 second interval near scan.
# 33 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a8bce290>
# 2022-06-17 19:32:12
# 36 flashes in 60 second interval near scan.
# 36 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a8aa5240>
# 2022-06-17 19:32:26
# 36 flashes in 60 second interval near scan.
# 36 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1a8ffa260>
# 2022-06-17 19:33:08
# 36 flashes in 60 second interval near scan.
# 36 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1
flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b71ad1e0>
# 2022-06-17 19:45:51
# 22 flashes in 60 second interval near scan.
# 22 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b7193340>
# 2022-06-17 19:46:05
# 19 flashes in 60 second interval near scan.
# 19 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b81e8070>
# 2022-06-17 19:46:48
# 11 flashes in 60 second interval near scan.
# 11 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b7efcb20>
# 2022-06-17 19:47:05
# 13 flashes in 60 second interval near scan.
# 13 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b8663460>
# 2022-06-17 19:47:23
# 22 flashes in 60 second interval near scan.
# 22 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b890bf10>
# 2022-06-17 19:47:40
# 23 flashes in 60 second interval near scan.
# 23 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b9937a60>
# 2022-06-17 19:48:24
# 21 flashes in 60 second interval near scan.
# 21 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b999d930>
# 2022-06-17 19:48:41
# 25 flashes in 60 second interval near scan.
# 25 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1b9fd4190>
# 2022-06-17 19:48:56
# 22 flashes in 60 second interval near scan.
# 22 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1ba963580>
# 2022-06-17 19:49:10
# 26 flashes in 60 second interval near scan.
# 26 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bb49f0a0>
# 2022-06-17 19:49:54
# 39 flashes in 60 second interval near scan.
# 39 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bb3bded0>
# 2022-06-17 19:50:10
# 41 flashes in 60 second interval near scan.
# 41 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bc0320e0>
# 2022-06-17 19:50:28
# 39 flashes in 60 second interval near scan.
# 39 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bc0308b0>
# 2022-06-17 19:50:43
# 45 flashes in 60 second interval near scan.
# 45 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bcf6f5e0>
# 2022-06-17 19:51:24
# 45 flashes in 60 second interval near scan.
# 45 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bcc76d40>
# 2022-06-17 19:51:41
# 38 flashes in 60 second interval near scan.
# 38 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bd76bc10>
# 2022-06-17 19:51:57
# 36 flashes in 60 second interval near scan.
# 36 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bdfea080>
# 2022-06-17 19:52:12
# 34 flashes in 60 second interval near scan.
# 34 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1be992f80>
# 2022-06-17 19:52:54
# 29 flashes in 60 second interval near scan.
# 29 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1be6a0ca0>
# 2022-06-17 19:53:11
# 30 flashes in 60 second interval near scan.
# 30 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bf3d3ee0>
# 2022-06-17 19:53:27
# 32 flashes in 60 second interval near scan.
# 32 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1bf3d2650>
# 2022-06-17 19:53:41
# 35 flashes in 60 second interval near scan.
# 35 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c022e650>
# 2022-06-17 19:54:21
# 45 flashes in 60 second interval near scan.
# 45 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c0c9f7c0>
# 2022-06-17 19:54:37
# 41 flashes in 60 second interval near scan.
# 41 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c07d0460>
# 2022-06-17 19:54:52
# 41 flashes in 60 second interval near scan.
# 41 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c120ef80>
# 2022-06-17 19:55:07
# 35 flashes in 60 second interval near scan.
# 35 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c1dc7bb0>
# 2022-06-17 19:55:50
# 34 flashes in 60 second interval near scan.
# 34 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c1dd83d0>
# 2022-06-17 19:56:07
# 33 flashes in 60 second interval near scan.
# 33 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c2cf5cf0>
# 2022-06-17 19:56:21
# 37 flashes in 60 second interval near scan.
# 37 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c2904c40>
# 2022-06-17 19:56:36
# 39 flashes in 60 second interval near scan.
# 39 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c375b400>
# 2022-06-17 19:57:14
# 36 flashes in 60 second interval near scan.
# 36 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c3758730>
# 2022-06-17 19:57:31
# 40 flashes in 60 second interval near scan.
# 40 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1c419b0a0>
# 2022-06-17 19:59:26
# 43 flashes in 60 second interval near scan.
# 43 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x1
flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21a99a890>
# 2022-06-17 21:37:17
# 74 flashes in 60 second interval near scan.
# 74 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21ae8d180>
# 2022-06-17 21:38:02
# 62 flashes in 60 second interval near scan.
# 62 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21b328850>
# 2022-06-17 21:38:22
# 64 flashes in 60 second interval near scan.
# 64 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21bbd1b70>
# 2022-06-17 21:38:40
# 69 flashes in 60 second interval near scan.
# 69 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21b926b00>
# 2022-06-17 21:38:56
# 73 flashes in 60 second interval near scan.
# 73 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21ccfb580>
# 2022-06-17 21:39:38
# 62 flashes in 60 second interval near scan.
# 62 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21c90c1f0>
# 2022-06-17 21:39:57
# 53 flashes in 60 second interval near scan.
# 53 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21cec4400>
# 2022-06-17 21:40:11
# 56 flashes in 60 second interval near scan.
# 56 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21d189000>
# 2022-06-17 21:40:28
# 64 flashes in 60 second interval near scan.
# 64 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21e7b3a60>
# 2022-06-17 21:41:11
# 73 flashes in 60 second interval near scan.
# 73 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21f32e530>
# 2022-06-17 21:41:26
# 69 flashes in 60 second interval near scan.
# 69 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21f0d54e0>
# 2022-06-17 21:41:41
# 62 flashes in 60 second interval near scan.
# 62 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x21f61b610>
# 2022-06-17 21:41:58
# 58 flashes in 60 second interval near scan.
# 58 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x220247220>
# 2022-06-17 21:42:41
# 70 flashes in 60 second interval near scan.
# 70 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2206a3310>
# 2022-06-17 21:42:56
# 75 flashes in 60 second interval near scan.
# 75 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2203bcbe0>
# 2022-06-17 21:43:10
# 65 flashes in 60 second interval near scan.
# 65 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x221053610>
# 2022-06-17 21:43:26
# 65 flashes in 60 second interval near scan.
# 65 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x221cbf610>
# 2022-06-17 21:44:11
# 71 flashes in 60 second interval near scan.
# 71 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22211ee00>
# 2022-06-17 21:44:27
# 63 flashes in 60 second interval near scan.
# 63 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x222269e10>
# 2022-06-17 21:44:42
# 65 flashes in 60 second interval near scan.
# 65 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x222cb66b0>
# 2022-06-17 21:44:57
# 64 flashes in 60 second interval near scan.
# 64 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22395a5f0>
# 2022-06-17 21:45:42
# 58 flashes in 60 second interval near scan.
# 58 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x223e0a4d0>
# 2022-06-17 21:45:57
# 62 flashes in 60 second interval near scan.
# 62 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x224336bc0>
# 2022-06-17 21:46:11
# 59 flashes in 60 second interval near scan.
# 59 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22478e110>
# 2022-06-17 21:46:28
# 61 flashes in 60 second interval near scan.
# 61 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2252e5a80>
# 2022-06-17 21:47:12
# 58 flashes in 60 second interval near scan.
# 58 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22540c0d0>
# 2022-06-17 21:47:32
# 54 flashes in 60 second interval near scan.
# 54 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x225b31690>
# 2022-06-17 21:47:51
# 53 flashes in 60 second interval near scan.
# 53 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x225d26770>
# 2022-06-17 21:48:08
# 55 flashes in 60 second interval near scan.
# 55 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x226a6fc10>
# 2022-06-17 21:48:55
# 59 flashes in 60 second interval near scan.
# 59 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x226a6f9a0>
# 2022-06-17 21:49:12
# 59 flashes in 60 second interval near scan.
# 59 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x226f25090>
# 2022-06-17 21:49:31
# 58 flashes in 60 second interval near scan.
# 58 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2279e6a10>
# 2022-06-17 21:49:47
# 52 flashes in 60 second interval near scan.
# 52 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2284ebcd0>
# 2022-06-17 21:50:34
# 48 flashes in 60 second interval near scan.
# 48 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2283056f0>
# 2022-06-17 21:50:51
# 50 flashes in 60 second interval near scan.
# 50 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2289961a0>
# 2022-06-17 21:51:04
# 52 flashes in 60 second interval near scan.
# 52 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x229348670>
# 2022-06-17 21:51:21
# 57 flashes in 60 second interval near scan.
# 57 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22a37b190>
# 2022-06-17 21:51:59
# 56 flashes in 60 second interval near scan.
# 56 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22a37a530>
# 2022-06-17 21:52:16
# 52 flashes in 60 second interval near scan.
# 52 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22aa50280>
# 2022-06-17 21:52:31
# 60 flashes in 60 second interval near scan.
# 60 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22ade8970>
# 2022-06-17 21:52:46
# 58 flashes in 60 second interval near scan.
# 58 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22be16f50>
# 2022-06-17 21:53:24
# 60 flashes in 60 second interval near scan.
# 60 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22c3d45b0>
# 2022-06-17 21:53:41
# 60 flashes in 60 second interval near scan.
# 60 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22c0ca380>
# 2022-06-17 21:53:56
# 59 flashes in 60 second interval near scan.
# 59 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22c7848b0>
# 2022-06-17 21:54:11
# 71 flashes in 60 second interval near scan.
# 71 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22d5d15d0>
# 2022-06-17 21:54:50
# 64 flashes in 60 second interval near scan.
# 64 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22d8c7520>
# 2022-06-17 21:55:06
# 64 flashes in 60 second interval near scan.
# 64 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22e11d2a0>
# 2022-06-17 21:55:21
# 55 flashes in 60 second interval near scan.
# 55 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22e3ddb10>
# 2022-06-17 21:55:34
# 65 flashes in 60 second interval near scan.
# 65 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22f35fc10>
# 2022-06-17 21:56:15
# 53 flashes in 60 second interval near scan.
# 53 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22f6862f0>
# 2022-06-17 21:56:31
# 45 flashes in 60 second interval near scan.
# 45 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x22fa9c0d0>
# 2022-06-17 21:56:47
# 47 flashes in 60 second interval near scan.
# 47 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x230659a80>
# 2022-06-17 21:57:00
# 45 flashes in 60 second interval near scan.
# 45 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x230e07d00>
# 2022-06-17 21:57:40
# 40 flashes in 60 second interval near scan.
# 40 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x230dd6110>
# 2022-06-17 21:57:56
# 42 flashes in 60 second interval near scan.
# 42 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x23139c130>
# 2022-06-17 21:58:09
# 47 flashes in 60 second interval near scan.
# 47 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x231a20b50>
# 2022-06-17 21:58:25
# 47 flashes in 60 second interval near scan.
# 47 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x232104af0>
# 2022-06-17 21:59:05
# 51 flashes in 60 second interval near scan.
# 51 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x231d16680>
# 2022-06-17 21:59:21
# 53 flashes in 60 second interval near scan.
# 53 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2328033a0>
# 2022-06-17 21:59:36
# 53 flashes in 60 second interval near scan.
# 53 flashes in 60 second interval near scan.
# Radar scan type: rhi
# Sweep:  0 of <pyart.core.radar.Radar object at 0x2329d1d80>
# 2022-06-17 21:59:51
# 52 flashes in 60 second interval near scan.
# 52 flashes in 60 second interval near scan.

# %%
# Does not provide a way to get the indices of the points inside the scan,
# so you lose the link to the third dimension.
# lma_in_rhi = lma_shp.intersection(scan_poly)
# for geom in lma_in_rhi.geoms:
#     print(geom)

# %%
# Example of finding nearby sources and their closest radar gate.
# R_cls, Z_cls, Y_min = subsetter.find_lightning_distances_near_scan_time(30, 1000)
# cls_r_idx, cls_az_idx, cls_elev_idx = subsetter.radar_gate_at_lightning_source(R_cls, Z_cls, Y_min)
